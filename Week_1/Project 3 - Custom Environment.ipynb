# %%
#https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %% [markdown]
# # 1. Import Dependencies

# %%
import gymnasium as gym 
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Types of Spaces

# %%
Discrete(3)
# Out:
# Discrete(3)

# %%
Box(0,1,shape=(3,3)).sample()
# Out:
# array([[0.9992809 , 0.32839844, 0.7395926 ],
#        [0.57921183, 0.6882018 , 0.33960867],
#        [0.27412984, 0.9018109 , 0.48158562]], dtype=float32)

# %%
Box(0,255,shape=(3,3), dtype=int).sample()
# Out:
# array([[ 27,  11, 175],
#        [ 18,  34,  36],
#        [181, 234, 188]])

# %%
Tuple((Discrete(2), Box(0,100, shape=(1,)))).sample()
# Out:
# (np.int64(0), array([89.51803], dtype=float32))

# %%
Dict({'height':Discrete(2), "speed":Box(0,100, shape=(1,))}).sample()
# Out:
# {'height': np.int64(0), 'speed': array([61.501575], dtype=float32)}

# %%
MultiBinary(4).sample()
# Out:
# array([1, 1, 1, 1], dtype=int8)

# %%
MultiDiscrete([5,2,2]).sample()
# Out:
# array([4, 0, 0])

# %% [markdown]
# # 3. Building an Environment

# %%
class ShowerEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def step(self, action):
        # Apply action
        self.state += action - 1

        # Reduce shower length
        self.shower_length -= 1

        # Reward logic
        reward = 1 if 37 <= self.state <= 39 else -1

        # Episode termination condition
        terminated = self.shower_length <= 0
        truncated = False  # Let Gym handle time truncation if needed externally

        info = {}
        return np.array([self.state], dtype=np.float32), reward, terminated, truncated, info

    def render(self):
        pass
    
    def reset(self, seed=None, options=None):
        # Reset the random seed
        super().reset(seed=seed)
        if seed is not None:
            np.random.seed(seed)
        self.state = 38 + random.randint(-3,3)
        # Reset shower time
        self.shower_length = 60 
        info = {}
        return np.array([self.state], dtype=np.float32), info

# %%
env=ShowerEnv()

# %%
env.observation_space.sample()
# Out:
# array([21.818592], dtype=float32)

# %%
env.reset()
# Out:
# (array([40.], dtype=float32), {})

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)

# %% [markdown]
# # 4. Test Environment

# %%
episodes = 5
for episode in range(1, episodes+1):
    state, _ = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated  # Only use terminated for ending episodes
        score += reward
    print(f'Episode:{episode} Score:{score}')
# Out:
# Episode:1 Score:-52
# Episode:2 Score:-10
# Episode:3 Score:-36
# Episode:4 Score:26
# Episode:5 Score:-60

# %%
env.close()

# %% [markdown]
# # 5. Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training\Logs\PPO_11
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -27.8    |
# | time/              |          |
# |    fps             | 3353     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.1       |
# | time/                   |             |
# |    fps                  | 1622        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008405151 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -6.01e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00466    |
# |    value_loss           | 51          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -27.1        |
# | time/                   |              |
# |    fps                  | 1463         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0075104055 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00169     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38           |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 69.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -27.4       |
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009850013 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -5.14e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 60          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.5       |
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007919333 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -7.69e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 64.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.1       |
# | time/                   |             |
# |    fps                  | 1303        |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005822724 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -9.78e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 65.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -27.4       |
# | time/                   |             |
# |    fps                  | 1278        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009529174 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 1.78e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000761   |
# |    value_loss           | 71.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -30.7       |
# | time/                   |             |
# |    fps                  | 1254        |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012604177 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -6.97e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 61.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -30.2       |
# | time/                   |             |
# |    fps                  | 1199        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011288378 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 1.74e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.5        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 81.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -30.4        |
# | time/                   |              |
# |    fps                  | 1145         |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0101964185 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -4.58e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.7         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00597     |
# |    value_loss           | 81.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29.7       |
# | time/                   |             |
# |    fps                  | 1113        |
# |    iterations           | 11          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.002222587 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 2.32e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.000279   |
# |    value_loss           | 72.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29         |
# | time/                   |             |
# |    fps                  | 1092        |
# |    iterations           | 12          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007643466 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 3.64e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.9        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.001      |
# |    value_loss           | 79.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.3       |
# | time/                   |             |
# |    fps                  | 1086        |
# |    iterations           | 13          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011995949 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -3.96e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.4        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 74.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -23.6        |
# | time/                   |              |
# |    fps                  | 1083         |
# |    iterations           | 14           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0069819517 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -2.03e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.6         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 81           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -23.1       |
# | time/                   |             |
# |    fps                  | 1077        |
# |    iterations           | 15          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012563398 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.00374     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.8        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 79.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -22.5       |
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 16          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008945743 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00345    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.9        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 70.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -21.1       |
# | time/                   |             |
# |    fps                  | 1070        |
# |    iterations           | 17          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.006958966 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.00228     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.7        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 74.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -20.9       |
# | time/                   |             |
# |    fps                  | 1060        |
# |    iterations           | 18          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005955125 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.0061     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.6        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 68          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -22.2      |
# | time/                   |            |
# |    fps                  | 1053       |
# |    iterations           | 19         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01323457 |
# |    clip_fraction        | 0.056      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.000558   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 31         |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0046    |
# |    value_loss           | 66.4       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -20.5        |
# | time/                   |              |
# |    fps                  | 1053         |
# |    iterations           | 20           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0056257625 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -0.00333     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.3         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 80           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -16.8        |
# | time/                   |              |
# |    fps                  | 1050         |
# |    iterations           | 21           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0035140563 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.000282    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.6         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 68.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -13.6       |
# | time/                   |             |
# |    fps                  | 1047        |
# |    iterations           | 22          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004861194 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 4.47e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00307    |
# |    value_loss           | 71.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -8.04       |
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 23          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004723368 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.00189     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.5        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 63.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -7.36        |
# | time/                   |              |
# |    fps                  | 1047         |
# |    iterations           | 24           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0064127645 |
# |    clip_fraction        | 0.0777       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0148       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.2         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00492     |
# |    value_loss           | 64.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -1.88        |
# | time/                   |              |
# |    fps                  | 1045         |
# |    iterations           | 25           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0063074613 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.00296     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.4         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 60.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 2.64        |
# | time/                   |             |
# |    fps                  | 1044        |
# |    iterations           | 26          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.005704974 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.00613     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.8        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 49.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 5.88        |
# | time/                   |             |
# |    fps                  | 1041        |
# |    iterations           | 27          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.011159662 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.00789    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00456    |
# |    value_loss           | 43.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 7.92        |
# | time/                   |             |
# |    fps                  | 1040        |
# |    iterations           | 28          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009042403 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | -0.00101    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.4        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 55.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 1040        |
# |    iterations           | 29          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008000961 |
# |    clip_fraction        | 0.0843      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.995      |
# |    explained_variance   | -6.37e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00559    |
# |    value_loss           | 47.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 22.8         |
# | time/                   |              |
# |    fps                  | 1038         |
# |    iterations           | 30           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0081965085 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.996       |
# |    explained_variance   | -0.000221    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.2         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00554     |
# |    value_loss           | 35.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 29.2         |
# | time/                   |              |
# |    fps                  | 1033         |
# |    iterations           | 31           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0073726317 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | -4.68e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 28.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 33           |
# | time/                   |              |
# |    fps                  | 1034         |
# |    iterations           | 32           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0064085773 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.972       |
# |    explained_variance   | -7.65e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.6         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 44.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34.1        |
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 33          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014173159 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | 2.64e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.4        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00304     |
# |    value_loss           | 46.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 29.2       |
# | time/                   |            |
# |    fps                  | 1028       |
# |    iterations           | 34         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01305376 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.978     |
# |    explained_variance   | 4.49e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.9       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.00138    |
# |    value_loss           | 48.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 27          |
# | time/                   |             |
# |    fps                  | 1021        |
# |    iterations           | 35          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012135269 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | 8.86e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29          |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 64.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 28.9        |
# | time/                   |             |
# |    fps                  | 1020        |
# |    iterations           | 36          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.014292356 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.000382    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 48.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 31.3        |
# | time/                   |             |
# |    fps                  | 1021        |
# |    iterations           | 37          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.013842732 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | 1.44e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00381     |
# |    value_loss           | 49          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 36.5        |
# | time/                   |             |
# |    fps                  | 1022        |
# |    iterations           | 38          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010360352 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.000109    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.9        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 56.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39.3        |
# | time/                   |             |
# |    fps                  | 1022        |
# |    iterations           | 39          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011701941 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.000201    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.1        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00634     |
# |    value_loss           | 55.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.9        |
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 40          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007374011 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.882      |
# |    explained_variance   | -1.49e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00217     |
# |    value_loss           | 67          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34.9        |
# | time/                   |             |
# |    fps                  | 1022        |
# |    iterations           | 41          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.029834194 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 6.97e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.5        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0033      |
# |    value_loss           | 77.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.7        |
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 42          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.015627854 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 4.09e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.9        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 89.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.3        |
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 43          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011826254 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.831      |
# |    explained_variance   | 0.00941     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00948    |
# |    value_loss           | 56.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 42.6        |
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 44          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.024729695 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.825      |
# |    explained_variance   | 0.00434     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00744     |
# |    value_loss           | 62.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.4        |
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 45          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004392102 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.815      |
# |    explained_variance   | 3.16e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00617     |
# |    value_loss           | 66.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 47.6         |
# | time/                   |              |
# |    fps                  | 1025         |
# |    iterations           | 46           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0150328465 |
# |    clip_fraction        | 0.169        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.843       |
# |    explained_variance   | -2.4e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.3         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.0069       |
# |    value_loss           | 76.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.5        |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 47          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011214955 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | -1.48e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.9        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00692     |
# |    value_loss           | 84.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.8        |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 48          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.016171373 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.835      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.6        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0196      |
# |    value_loss           | 82.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 45.7       |
# | time/                   |            |
# |    fps                  | 1025       |
# |    iterations           | 49         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.02592802 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.839     |
# |    explained_variance   | -1.19e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.8       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.00608    |
# |    value_loss           | 90.4       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 45.7       |
# | time/                   |            |
# |    fps                  | 1023       |
# |    iterations           | 50         |
# |    time_elapsed         | 100        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01535108 |
# |    clip_fraction        | 0.168      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.82      |
# |    explained_variance   | 2.09e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57.2       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00634   |
# |    value_loss           | 95         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.5        |
# | time/                   |             |
# |    fps                  | 1022        |
# |    iterations           | 51          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.017521806 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 2.5e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.6        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0108      |
# |    value_loss           | 86          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 41.8       |
# | time/                   |            |
# |    fps                  | 1021       |
# |    iterations           | 52         |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.01709221 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.758     |
# |    explained_variance   | 6.02e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.9       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.007     |
# |    value_loss           | 87.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 1021        |
# |    iterations           | 53          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.021091163 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.727      |
# |    explained_variance   | 0.00676     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.6        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 78.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.2        |
# | time/                   |             |
# |    fps                  | 1021        |
# |    iterations           | 54          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.009447744 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.00733     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 68          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 43.5       |
# | time/                   |            |
# |    fps                  | 1017       |
# |    iterations           | 55         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.00735961 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.644     |
# |    explained_variance   | 0.00658    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.1       |
# |    n_updates            | 540        |
# ...
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 994         |
# |    iterations           | 179         |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.014717718 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.347      |
# |    explained_variance   | 5.36e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 57.6        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | 0.00819     |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.2        |
# | time/                   |             |
# |    fps                  | 995         |
# |    iterations           | 180         |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.017869392 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.369      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.3        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.00801     |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.7        |
# | time/                   |             |
# |    fps                  | 995         |
# |    iterations           | 181         |
# |    time_elapsed         | 372         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.009314299 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.344      |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73          |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | 0.00745     |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55.4        |
# | time/                   |             |
# |    fps                  | 995         |
# |    iterations           | 182         |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.008938658 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.328      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.2        |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.00602     |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.4        |
# | time/                   |             |
# |    fps                  | 996         |
# |    iterations           | 183         |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.027372614 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.365      |
# |    explained_variance   | 7.75e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60          |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.0132      |
# |    value_loss           | 115         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 54.1         |
# | time/                   |              |
# |    fps                  | 996          |
# |    iterations           | 184          |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0035995184 |
# |    clip_fraction        | 0.0759       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.346       |
# |    explained_variance   | 7.51e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 73.9         |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | 0.00871      |
# |    value_loss           | 121          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 50.1       |
# | time/                   |            |
# |    fps                  | 996        |
# |    iterations           | 185        |
# |    time_elapsed         | 380        |
# |    total_timesteps      | 378880     |
# | train/                  |            |
# |    approx_kl            | 0.00697978 |
# |    clip_fraction        | 0.0646     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.341     |
# |    explained_variance   | 0.000227   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 62.7       |
# |    n_updates            | 1840       |
# |    policy_gradient_loss | 0.00525    |
# |    value_loss           | 110        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 49           |
# | time/                   |              |
# |    fps                  | 996          |
# |    iterations           | 186          |
# |    time_elapsed         | 382          |
# |    total_timesteps      | 380928       |
# | train/                  |              |
# |    approx_kl            | 0.0074764197 |
# |    clip_fraction        | 0.0865       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.351       |
# |    explained_variance   | 0.00144      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 74.5         |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 121          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.5        |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 187         |
# |    time_elapsed         | 384         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.019620515 |
# |    clip_fraction        | 0.0856      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.364      |
# |    explained_variance   | 0.0155      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.2        |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | 0.00273     |
# |    value_loss           | 98.1        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 54.6      |
# | time/                   |           |
# |    fps                  | 997       |
# |    iterations           | 188       |
# |    time_elapsed         | 385       |
# |    total_timesteps      | 385024    |
# | train/                  |           |
# |    approx_kl            | 0.0224303 |
# |    clip_fraction        | 0.0716    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.351    |
# |    explained_variance   | 0.00814   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 36.7      |
# |    n_updates            | 1870      |
# |    policy_gradient_loss | 0.00548   |
# |    value_loss           | 93.2      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.2        |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 189         |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.015409339 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.303      |
# |    explained_variance   | -0.0017     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.4        |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | 0.014       |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.8        |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 190         |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.007355932 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.291      |
# |    explained_variance   | -0.00195    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.6        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | 0.0084      |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.7        |
# | time/                   |             |
# |    fps                  | 998         |
# |    iterations           | 191         |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.039032716 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.31       |
# |    explained_variance   | -0.000219   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.6        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.0101      |
# |    value_loss           | 112         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54.7        |
# | time/                   |             |
# |    fps                  | 998         |
# |    iterations           | 192         |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.009531012 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.332      |
# |    explained_variance   | -2.49e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.8        |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.007       |
# |    value_loss           | 112         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 55.1       |
# | time/                   |            |
# |    fps                  | 998        |
# |    iterations           | 193        |
# |    time_elapsed         | 395        |
# |    total_timesteps      | 395264     |
# | train/                  |            |
# |    approx_kl            | 0.07996452 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.383     |
# |    explained_variance   | -4.18e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 68.7       |
# |    n_updates            | 1920       |
# |    policy_gradient_loss | 0.0263     |
# |    value_loss           | 116        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 55.1         |
# | time/                   |              |
# |    fps                  | 999          |
# |    iterations           | 194          |
# |    time_elapsed         | 397          |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 0.0068488633 |
# |    clip_fraction        | 0.0824       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.337       |
# |    explained_variance   | -2.74e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.4         |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | 0.00904      |
# |    value_loss           | 113          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 56.7         |
# | time/                   |              |
# |    fps                  | 999          |
# |    iterations           | 195          |
# |    time_elapsed         | 399          |
# |    total_timesteps      | 399360       |
# | train/                  |              |
# |    approx_kl            | 0.0068542194 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.353       |
# |    explained_variance   | -3.21e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.2         |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | 0.00874      |
# |    value_loss           | 115          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.7        |
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 196         |
# |    time_elapsed         | 401         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.021629361 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.362      |
# |    explained_variance   | -1.24e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.2        |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.00798     |
# |    value_loss           | 118         |
# -----------------------------------------

# %% [markdown]
# # 6. Save Model

# %%
model.save('PPO')

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (np.float64(47.4), np.float64(35.811171441325406))
