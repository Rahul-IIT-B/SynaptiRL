# %%
import numpy as np
if not hasattr(np, 'bool8'):
    np.bool8 = np.bool_

import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = 'CartPole-v1'
env = gym.make(environment_name, render_mode="rgb_array")

# %%
episodes = 5
for episode in range(1, episodes+1):
    state, _ = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Episode:1 Score:12.0
# Episode:2 Score:21.0
# Episode:3 Score:64.0
# Episode:4 Score:11.0
# Episode:5 Score:31.0

# %%
log_path = os.path.join('Training', 'Logs')

env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 1537 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 659         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009597906 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.000715    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.45        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 48.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 612        |
# |    iterations           | 3          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01020165 |
# |    clip_fraction        | 0.0625     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.669     |
# |    explained_variance   | 0.0922     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.8       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0157    |
# |    value_loss           | 32.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009951895 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 49.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 5           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006009615 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.615      |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 65.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 555         |
# |    iterations           | 6           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005042571 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.1        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 51.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 7           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010152696 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.66        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 39.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 547        |
# |    iterations           | 8          |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00350384 |
# |    clip_fraction        | 0.0243     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.586     |
# |    explained_variance   | 0.675      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.3       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0067    |
# |    value_loss           | 54.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004617659 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.54        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00967    |
# |    value_loss           | 39.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 547          |
# |    iterations           | 10           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0095263785 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.586       |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.72         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0162      |
# |    value_loss           | 24.5         |
# ------------------------------------------

# %%
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole')
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:259: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (np.float64(453.7), np.float64(62.11932066595706))

# %%
env.close()

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
# env.close()
# Out:
# Episode:1 Score:[363.]
# Episode:2 Score:[500.]
# Episode:3 Score:[486.]
# Episode:4 Score:[251.]
# Episode:5 Score:[206.]

# %%
env.close()

# %%
training_log_path = os.path.join(log_path, 'PPO_1')
# !tensorboard --logdir={training_log_path}
# Out:
# c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\tensorboard\default.py:30: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Scripts\tensorboard.exe\__main__.py", line 4, in <module>
#     from tensorboard.main import run_main
#   File "c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\tensorboard\main.py", line 27, in <module>
#     from tensorboard import default
#   File "c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\tensorboard\default.py", line 40, in <module>
#     from tensorboard.plugins.image import images_plugin
#   File "c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\tensorboard\plugins\image\images_plugin.py", line 18, in <module>
#     import imghdr
# ModuleNotFoundError: No module named 'imghdr'

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
save_path = os.path.join('Training', 'Saved Models')
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=500, verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_6
# -----------------------------
# | time/              |      |
# |    fps             | 2387 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1296        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008445682 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00372    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.54        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 48.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1184        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011226958 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.0869      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 35.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1126        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010302428 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 47.4        |
# -----------------------------------------
# c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=395.60 +/- 95.82
# Episode length: 395.60 +/- 95.82
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 396          |
# |    mean_reward          | 396          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0064241155 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0149      |
# |    value_loss           | 61.8         |
# ------------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 1040  |
# |    iterations      | 5     |
# |    time_elapsed    | 9     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 984         |
# |    iterations           | 6           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008381534 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.9        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 60.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012265005 |
# |    clip_fraction        | 0.0933      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.4        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 49.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 8            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0047492087 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.603        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00955     |
# |    value_loss           | 54.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 936         |
# |    iterations           | 9           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016612343 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.25        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00991    |
# |    value_loss           | 16.7        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.005727197 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.2         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 16.5        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 500.00  is above the threshold 500

# %%
net_arch = dict(pi=[128,128,128,128], vf=[128,128,128,128])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_7
# -----------------------------
# | time/              |      |
# |    fps             | 2444 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1029       |
# |    iterations           | 2          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01457873 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.682     |
# |    explained_variance   | -0.00217   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.02       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0249    |
# |    value_loss           | 20.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 883        |
# |    iterations           | 3          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.02001491 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.64      |
# |    explained_variance   | 0.453      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.41       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0366    |
# |    value_loss           | 25.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013676781 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.58        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 45.1        |
# -----------------------------------------
# c:\Users\rahul\OneDrive\Desktop\Synaptic_RL\.venv\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=456.00 +/- 67.40
# Episode length: 456.00 +/- 67.40
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 456          |
# |    mean_reward          | 456          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0090819225 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0192      |
# |    value_loss           | 41.5         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 655   |
# |    iterations      | 5     |
# |    time_elapsed    | 15    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 637         |
# |    iterations           | 6           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008238756 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.49        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 26.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 7           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010067625 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.536      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.679       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00648    |
# |    value_loss           | 9.43        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  |
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000336 |
# |    n_updates        | 1164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1129     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4798     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00174  |
# |    n_updates        | 1174     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1130     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4840     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000865 |
# |    n_updates        | 1184     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1130     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4879     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000357 |
# |    n_updates        | 1194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1129     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4917     |
# | train/              |          |
# ...
# |    n_updates        | 4635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1860     |
# |    fps              | 855      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 18683    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0404   |
# |    n_updates        | 4645     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1864     |
# |    fps              | 853      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 18723    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0424   |
# |    n_updates        | 4655     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1868     |
# |    fps              | 852      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18763    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 4665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1872     |
# |    fps              | 851      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18801    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 4675     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1876     |
# |    fps              | 849      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18837    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0328   |
# |    n_updates        | 4684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1880     |
# |    fps              | 848      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18874    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.05     |
# |    n_updates        | 4693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1884     |
# |    fps              | 846      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18913    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 4703     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1888     |
# |    fps              | 845      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18947    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 4711     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1892     |
# |    fps              | 844      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 18984    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 4720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1896     |
# |    fps              | 842      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 19023    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0309   |
# |    n_updates        | 4730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1900     |
# |    fps              | 841      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 19062    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0226   |
# |    n_updates        | 4740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1904     |
# |    fps              | 839      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 19105    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 4751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1908     |
# |    fps              | 839      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 19144    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0241   |
# |    n_updates        | 4760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1912     |
# |    fps              | 838      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 19180    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 4769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1916     |
# |    fps              | 837      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 19219    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.047    |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1920     |
# |    fps              | 836      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19256    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0411   |
# |    n_updates        | 4788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1924     |
# |    fps              | 834      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19293    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 4798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1928     |
# |    fps              | 832      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19330    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0403   |
# |    n_updates        | 4807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1932     |
# |    fps              | 831      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19365    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 4816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1936     |
# |    fps              | 830      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19402    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 4825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1940     |
# |    fps              | 829      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19442    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.038    |
# |    n_updates        | 4835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1944     |
# |    fps              | 829      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19476    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 4843     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1948     |
# |    fps              | 828      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19515    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.069    |
# |    n_updates        | 4853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1952     |
# |    fps              | 826      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19552    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0319   |
# |    n_updates        | 4862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1956     |
# |    fps              | 825      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19589    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 4872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1960     |
# |    fps              | 823      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19625    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0406   |
# |    n_updates        | 4881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1964     |
# |    fps              | 822      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 19663    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.033    |
# |    n_updates        | 4890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1968     |
# |    fps              | 820      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19702    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0384   |
# |    n_updates        | 4900     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1972     |
# |    fps              | 818      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19743    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 4910     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1976     |
# |    fps              | 816      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19783    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 4920     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1980     |
# |    fps              | 815      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19819    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0288   |
# |    n_updates        | 4929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1984     |
# |    fps              | 813      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19858    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 4939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1988     |
# |    fps              | 812      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19897    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 4949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1992     |
# |    fps              | 811      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19936    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 4958     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1996     |
# |    fps              | 811      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 19970    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 4967     |
# ----------------------------------
